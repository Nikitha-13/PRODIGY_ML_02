# %% [markdown]
# <a href="https://www.kaggle.com/code/nikithapindi/prodigy-ml-02?scriptVersionId=145126839" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !git clone https://github.com/Nikitha-13/PRODIGY_ML_02.git

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv('/kaggle/input/customer-segmentation-tutorial-in-python/Mall_Customers.csv')
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.duplicated().sum()

# %%
df.describe()

# %%
plt.figure(1, figsize=(16,10))
sns.pairplot(data=df, hue= 'Gender')
plt.show()

# %%
plt.figure(1, figsize=(4,4))
sns.countplot(x= 'Gender', data=df)
plt.show()

# %%
plt.figure(1, figsize=(16,4))
n = 0
for x in ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']:
    n += 1
    plt.subplot(1, 3, n)
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    sns.distplot(df[x] , bins=10)
    plt.title('Distplot of {}'.format(x))
    plt.show()

# %%
x = df.iloc[:, -2:]

# %%
km_inertias, km_scores = [], []

for k in range(2, 11):
    km = KMeans(n_clusters=k).fit(x)
    km_inertias.append(km.inertia_)
    km_scores.append(silhouette_score(x, km.labels_))
sns.lineplot(x=range(2,11), y=km_inertias)
plt.title('elbow graph / inertia depending on k')
plt.show()

# %%
sns.lineplot(x=range(2, 11), y=km_scores)
plt.title('scores depending on k')
plt.show()

# %%
x = df.iloc[:, -3:]

# %%
km_inertias, km_scores = [], []

for k in range(2, 11):
    km = KMeans(n_clusters=k).fit(x)
    km_inertias.append(km.inertia_)
    km_scores.append(silhouette_score(x, km.labels_))
sns.lineplot(x=range(2, 11), y=km_inertias)
plt.title('elbow graph / inertia depending on k')
plt.show()

# %%
sns.lineplot(x=range(2, 11), y=km_scores)
plt.title('scores depending on k')
plt.show()

# %%
km = KMeans(n_clusters=5).fit(x)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x.iloc[:, 1], y=x.iloc[:, 2], hue=km.labels_)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=x.iloc[:, 0], y=x.iloc[:, 1], hue=km.labels_)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=x.iloc[:, 0], y=x.iloc[:, 2], hue=km.labels_)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8,8))
ax = Axes3D(fig)

xs = x.iloc[:, 0]
ys = x.iloc[:, 1]
zs = x.iloc[:, 2]
ax.scatter(xs, ys, zs, s=50, alpha = 0.6, c=km.labels_)

ax.set_xlabel('Age')
ax.set_ylabel('Annual Income')
ax.set_zlabel('Spending score')

plt.show()

# %%
x['label'] = km.labels_

# %%
x.label.value_counts()

# %%
for k in range(5):
    print(f'cluster nb : {k}')
    print(x[x.label == k].describe().iloc[[0, 1, 3, 7], :-1])
    print('\n\n')

# %%
x[x.label == 1].describe().iloc[[0, 1, 3, 7], :-1]
